# %%
my_list = ["E", "Z", "R", 1, 2, 3]
my_tuple = ("L", "E", "O")
my_data = []

for data in zip(my_list, my_tuple):
    my_data.append(data)
    for item in data:
        print(item, end="")

# %%
my_list1 = ["E", "L", "Z", "E", "R", "O", 1, 2]
my_tuple = ("E", "Z", "R", 1, 2, "E", "R", "O")
my_list2 = ("L", "E", "O", 1, 2, "E", "R", "O")
my_data = []

for item1, item2, item3 in zip(my_list1, my_tuple, my_list2):
    if isinstance(item1, str):
        my_data.append(item1) 

for item in my_data:
    print(item, end="")

# البتاع دا رخم فشخ

# %%
from PIL import Image

image = Image.open("C:\\Users\\Hany\\OneDrive\\Pictures\\Screenshots\\elzero-pillow.png")
image = image.crop((400, 0, 800, 400)).convert("L")
image.show()

image2 = Image.open("C:\\Users\\Hany\\OneDrive\\Pictures\\Screenshots\\elzero-pillow.png")
image2 = image2.crop((0, 400, 1200, 800)).convert("L").transpose(Image.FLIP_LEFT_RIGHT).transpose(Image.FLIP_TOP_BOTTOM)
image2.show()
